# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt 
import datetime as dt
import pandas as pd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from scipy.optimize import minimize
import matplotlib.backends.backend_pdf
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import pickle
import matplotlib.colors as Colors
from numba import jit
from multiprocessing import Pool
import os
import Rheology_fitting_toolkit as rft
from sklearn.metrics import mean_squared_error
import math
import creep_part_identify as cpi
# Out:
# /tmp/ipykernel_241931/4207224591.py:16: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
dictionary_all_events = {}
CREEPMETER = ['XHR']

for q in range(len(CREEPMETER)):
    print(CREEPMETER[q])
    tm, min10_creep, tm2, min10_creep2 = rft.import_text(CREEPMETER[q])

    if CREEPMETER[q] == 'XSJ' or CREEPMETER[q] == 'XHR' or CREEPMETER[q] == 'XPK':
        tm_int, min10_creep_int = rft.interpolate(tm,min10_creep,CREEPMETER)
        tm_int2, min10_creep_int2 = rft.interpolate(tm2,min10_creep2,CREEPMETER)
    elif CREEPMETER[q] == 'XMR':
        tm_int, min10_creep_int = rft.interpolate(tm,min10_creep,CREEPMETER)
        tm_int2, min10_creep_int2 = rft.interpolate_1min(tm2,min10_creep2,CREEPMETER)
    else:
        tm_int, min10_creep_int = rft.interpolate(tm,min10_creep,CREEPMETER)


    df_PICKS, duration, START = rft.creepmeter_events(CREEPMETER[q])

    if CREEPMETER[q] == 'XSJ' or CREEPMETER[q] == 'XHR' or CREEPMETER[q] == 'XPK':
        data1  = rft.vel_acc(tm_int,min10_creep_int,10/60)
        data2 = rft.vel_acc(tm_int2,min10_creep_int2,10/60)
        data = data1.append(data2,ignore_index=True)
    elif CREEPMETER[q] == 'XMR':
        data1  = rft.vel_acc(tm_int,min10_creep_int,10/60)
        data2 = rft.vel_acc_1min(tm_int2,min10_creep_int2,1/60)
        data = data1.append(data2,ignore_index=True)
    else:
        data = rft.vel_acc(tm_int,min10_creep_int,10/60)


    df_auto = rft.parkfield_remover(df_PICKS,CREEPMETER[q])


    df_rain_day_total = rft.rain_timeseries(CREEPMETER[q])

    df_auto = rft.when_does_it_rain(df_auto,CREEPMETER[q])
    
    if CREEPMETER[q] == 'CWN':
        C_matrix = np.load('../../Rheology/CWN/CWN_covariance_matrix_12days_18_APR_23.npy')
        C_matrix_inv_CWN = np.linalg.inv(C_matrix)
    
    if CREEPMETER[q] == 'XHR':
        C_matrix_2 = np.load('../../Rheology/XHR/XHR_2_covariance_matrix_4days_27_APR_23.npy')
        C_matrix_3 = np.load('../../Rheology/XHR/XHR_3_covariance_matrix_4days_27_APR_23.npy')
        C_matrix_inv_2 = np.linalg.inv(C_matrix_2)
        C_matrix_inv_3 = np.linalg.inv(C_matrix_3)
    
    
    dataframes_long, creep_index_long = rft.creep_event_dataframe(df_auto,duration, START, data,CREEPMETER[q])
    dataframes, creep_index = rft.creep_event_dataframe_short(dataframes_long,df_auto)

    Creep_phases = pd.read_csv("../../Rheology/{k}/Creep_phases_{k}.csv".format(k=CREEPMETER[q]),index_col=0)
# Out:
# XHR

# %%
import importlib
importlib.reload(rft)
# Out:
# <module 'Rheology_fitting_toolkit' from '/home/users/exet4136/CREEPMETER_DATA/SCRIPTS/Onset/Rheology_fitting_toolkit.py'>

# %%
def LNV_fitter(time,slip,cov_matrix_inv,no_phases,columns_LNV,j,CREEPMETER,LNV_DF_params,atest,file_misfit):
    print('Linear Viscous: {k}'.format(k=j))
    print ("Current date and time : ")
    
    print (dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    isExistLNV = os.path.exists('/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{y}/LNV/{k}_{y}_LNV_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt'.format(k=CREEPMETER,y=j))
    if not isExistLNV:
        success = False
        n_iter = 5000
        LNV_bounds = LNV_DF_params.loc['bounds'].to_list()
        LNV_initial_guess = LNV_DF_params.loc['initial'].to_list()
        while success == False:
            if success == False:
                res_LNV = scipy.optimize.basinhopping(rft.LNV_dromedary, LNV_initial_guess,\
                accept_test = atest, minimizer_kwargs = ({'args':(time,slip,cov_matrix_inv,no_phases,\
                columns_LNV,j,CREEPMETER,file_misfit),'method':'SLSQP','bounds':LNV_bounds}))#,'options':{'maxiter':n_iter}}),niter=1000)            
                n_iter = n_iter+2000
                success = res_LNV.success
                LNV_initial_guess = res_LNV.x
        dictionary_LNV = {}
        dictionary_LNV['fit'] = res_LNV
        LNV_fitting_params = pd.DataFrame([res_LNV.x],columns = ('Ts','Vs','K','T01','S1','Tau1','V01','T02','S2'), index = ['fitted'])
        LNV_DF_params = pd.concat([LNV_DF_params,LNV_fitting_params])
        dictionary_LNV['fitting params'] = LNV_DF_params
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/LNV/{k}_{u}_LNV_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "wb") as tf:
            pickle.dump(dictionary_LNV,tf)
    else:
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/LNV/{k}_{u}_LNV_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "rb") as tf:
            dictionary_LNV = pickle.load(tf)
            res_LNV = dictionary_LNV['fit']
            LNV_DF_params = dictionary_LNV['fitting params']
    return LNV_DF_params

###################################################################################################
def PLV_fitter(time,slip,cov_matrix_inv,no_phases,columns_PLV,j,CREEPMETER,PLV_DF_params,atest,file_misfit):
    print('Power-law Viscous: {k}'.format(k=j))
    print ("Current date and time : ")
    print (dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    isExistPLV = os.path.exists('/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{y}/PLV/{k}_{y}_PLV_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt'.format(k=CREEPMETER,y=j))
    if not isExistPLV:
        success = False
        n_iter = 5000
        PLV_bounds = PLV_DF_params.loc['bounds'].to_list()
        PLV_initial_guess = PLV_DF_params.loc['initial'].to_list()
        while success == False:
            if success == False:
                res_PLV = scipy.optimize.basinhopping(rft.PLV_dromedary, PLV_initial_guess,\
                accept_test= atest, minimizer_kwargs = ({'args':(time,slip,cov_matrix_inv,no_phases,\
                columns_PLV,j,CREEPMETER,file_misfit),'method':'SLSQP','bounds':PLV_bounds}))#,'options':{'maxiter':n_iter}}),niter=1000)
                n_iter = n_iter+2000
                success = res_PLV.success
                PLV_initial_guess = res_PLV.x

        dictionary_PLV = {}
        dictionary_PLV['fit'] = res_PLV
        PLV_fitting_params = pd.DataFrame([res_PLV.x],columns = ('Ts','Vs','K','T01','S1','Tau1','V01','n1','T02','S2'), index = ['fitted'])
        PLV_DF_params = pd.concat([PLV_DF_params,PLV_fitting_params])
        dictionary_PLV['fitting params'] = PLV_DF_params
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/PLV/{k}_{u}_PLV_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "wb") as tf:
            pickle.dump(dictionary_PLV,tf)
    else:
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/PLV/{k}_{u}_PLV_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "rb") as tf:
            dictionary_PLV = pickle.load(tf)
            res_PLV = dictionary_PLV['fit']
            PLV_DF_params = dictionary_PLV['fitting params']
    return PLV_DF_params
###################################################################################################
def VSF_SS_fitter(time,slip,cov_matrix_inv,no_phases,columns_VSF_SS,j,CREEPMETER,VSF_SS_DF_params,atest,file_misfit):
    print('VSF-SS: {k}'.format(k=j))
    print ("Current date and time : ")
    print (dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    isExistVSF_SS = os.path.exists('/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{y}/VSF_SS/{k}_{y}_VSF_SS_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt'.format(k=CREEPMETER,y=j))
    if not isExistVSF_SS:
        success = False
        n_iter = 5000
        VSF_SS_bounds = VSF_SS_DF_params.loc['bounds'].to_list()
        VSF_SS_initial_guess = VSF_SS_DF_params.loc['initial'].to_list()
        while success == False:
            if success == False:
                res_VSF_SS = scipy.optimize.basinhopping(rft.VSF_SS_dromedary, VSF_SS_initial_guess,\
                accept_test = atest, minimizer_kwargs = ({'args':(time,slip,cov_matrix_inv,no_phases,\
                columns_VSF_SS,j,CREEPMETER,file_misfit),'method':'SLSQP','bounds':VSF_SS_bounds}))#,'options':{'maxiter':n_iter}}),niter=1000)
                n_iter = n_iter+2000
                success = res_VSF_SS.success
                VSF_SS_initial_guess = res_VSF_SS.x

        dictionary_VSF_SS = {}
        dictionary_VSF_SS['fit'] = res_VSF_SS
        VSF_SS_fitting_params = pd.DataFrame([res_VSF_SS.x],columns = ('Ts','Vs','K','T01','S1','Tau1','V01','T02','S2'), index = ['fitted'])
        VSF_SS_DF_params = pd.concat([VSF_SS_DF_params,VSF_SS_fitting_params])
        dictionary_VSF_SS['fitting params'] = VSF_SS_DF_params
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/VSF_SS/{k}_{u}_VSF_SS_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "wb") as tf:
            pickle.dump(dictionary_VSF_SS,tf)
    else:
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/VSF_SS/{k}_{u}_VSF_SS_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "rb") as tf:
            dictionary_VSF_SS = pickle.load(tf)
            res_VSF_SS = dictionary_VSF_SS['fit']
            VSF_SS_DF_params = dictionary_VSF_SS['fitting params']
    return VSF_SS_DF_params
###################################################################################################
def RDF_fitter(time,slip,cov_matrix_inv,no_phases,columns_RDF,j,CREEPMETER,RDF_DF_params,atest,file_misfit):
    print('RDF: {k}'.format(k=j))
    print ("Current date and time : ")
    print (dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    isExistRDF = os.path.exists('../../Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{y}/RDF/{k}_{y}_RDF_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt'.format(k=CREEPMETER,y=j))
    if not isExistRDF:
        success = False
        n_iter = 5000
        RDF_bounds = RDF_DF_params.loc['bounds'].to_list()
        RDF_initial_guess = RDF_DF_params.loc['initial'].to_list()
        while success == False:
            if success == False:
                res_RDF = scipy.optimize.basinhopping(rft.RDF_dromedary, RDF_initial_guess,\
                accept_test = atest, minimizer_kwargs = ({'args':(time,slip,cov_matrix_inv,no_phases,\
                columns_RDF,j,CREEPMETER,file_misfit),'method':'SLSQP','bounds':RDF_bounds}))#,'options':{'maxiter':n_iter}}),niter=1000)
                n_iter = n_iter+2000
                success = res_RDF.success
                RDF_initial_guess = res_RDF.x
        dictionary_RDF = {}
        dictionary_RDF['fit'] = res_RDF
        RDF_fitting_params = pd.DataFrame([res_RDF.x],columns = ('Ts','Vs','K','T01','S1','Ta1','V01','V0/VL1','T02','S2'), index = ['fitted'])
        RDF_DF_params = pd.concat([RDF_DF_params,RDF_fitting_params])
        dictionary_RDF['fitting params'] = RDF_DF_params
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/RDF/{k}_{u}_RDF_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "wb") as tf:
            pickle.dump(dictionary_RDF,tf)

    else:
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/RDF/{k}_{u}_RDF_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "rb") as tf:
            dictionary_RDF = pickle.load(tf)
            res_RDF = dictionary_RDF['fit']
            RDF_DF_params = dictionary_RDF['fitting params']
    return RDF_DF_params
###################################################################################################
def VSF_aSS_fitter(time,slip,cov_matrix_inv,no_phases,columns_VSF_aSS,j,CREEPMETER,VSF_aSS_DF_params,atest,file_misfit):
    print('VSF_aSS: {k}'.format(k=j))
    print ("Current date and time : ")
    print (dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    isExistVSF_aSS = os.path.exists('../../Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{y}/VSF_aSS/{k}_{y}_VSF_aSS_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt'.format(k=CREEPMETER,y=j))
    if not isExistVSF_aSS:
        success = False
        n_iter = 5000
        VSF_aSS_bounds = VSF_aSS_DF_params.loc['bounds'].to_list()
        VSF_aSS_initial_guess = VSF_aSS_DF_params.loc['initial'].to_list()
        while success == False:
            if success == False:
                res_VSF_aSS = scipy.optimize.basinhopping(rft.VSF_aSS_dromedary, VSF_aSS_initial_guess,\
                accept_test = atest, minimizer_kwargs = ({'args':(time,slip,cov_matrix_inv,no_phases,\
                columns_VSF_aSS,j,CREEPMETER,file_misfit),'method':'SLSQP','bounds':VSF_aSS_bounds}))#,'options':{'maxiter':n_iter}}),niter=1000)
                n_iter = n_iter+2000
                success = res_VSF_aSS.success
                VSF_aSS_initial_guess = res_VSF_aSS.x
        dictionary_VSF_aSS = {}
        dictionary_VSF_aSS['fit'] = res_VSF_aSS
        VSF_aSS_fitting_params = pd.DataFrame([res_VSF_aSS.x],columns = ('Ts','Vs','K','T01','S1','Ta1','V01','t1','T02','S2'), index = ['fitted'])
        VSF_aSS_DF_params = pd.concat([VSF_aSS_DF_params,VSF_aSS_fitting_params])
        dictionary_VSF_aSS['fitting params'] = VSF_aSS_DF_params
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/VSF_aSS/{k}_{u}_VSF_aSS_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "wb") as tf:
            pickle.dump(dictionary_VSF_aSS,tf)

    else:
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/VSF_aSS/{k}_{u}_VSF_aSS_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "rb") as tf:
            dictionary_VSF_aSS = pickle.load(tf)
            res_VSF_aSS = dictionary_VSF_aSS['fit']
            VSF_aSS_DF_params = dictionary_VSF_aSS['fitting params']
    return VSF_aSS_DF_params
###################################################################################################
def VSF_bSS_fitter(time,slip,cov_matrix_inv,no_phases,columns_VSF_bSS,j,CREEPMETER,VSF_bSS_DF_params,atest,file_misfit):
    print('VSF-bSS: {k}'.format(k=j))
    print ("Current date and time : ")
    print (dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    isExistVSF_bSS = os.path.exists('/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{y}/VSF_bSS/{k}_{y}_VSF_bSS_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt'.format(k=CREEPMETER,y=j))
    if not isExistVSF_bSS:
        success = False
        n_iter = 5000
        VSF_bSS_bounds = VSF_bSS_DF_params.loc['bounds'].to_list()
        VSF_bSS_initial_guess = VSF_bSS_DF_params.loc['initial'].to_list()
        while success == False:
            if success == False:
                res_VSF_bSS = scipy.optimize.basinhopping(rft.VSF_bSS_dromedary, VSF_bSS_initial_guess,\
                accept_test = atest, minimizer_kwargs = ({'args':(time,slip,cov_matrix_inv,no_phases,\
                columns_VSF_bSS,j,CREEPMETER,file_misfit),'method':'SLSQP','bounds':VSF_bSS_bounds}))#,'options':{'maxiter':n_iter}}),niter=1000)
                n_iter = n_iter+2000
                success = res_VSF_bSS.success
                VSF_bSS_initial_guess = res_VSF_bSS.x

        dictionary_VSF_bSS = {}
        dictionary_VSF_bSS['fit'] = res_VSF_bSS
        VSF_bSS_fitting_params = pd.DataFrame([res_VSF_bSS.x],columns = ('Ts','Vs','K','T01','S1','Tau1','V01','A_B1','T02','S2'), index = ['fitted'])
        VSF_bSS_DF_params = pd.concat([VSF_bSS_DF_params,VSF_bSS_fitting_params])
        dictionary_VSF_bSS['fitting params'] = VSF_bSS_DF_params
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/VSF_bSS/{k}_{u}_VSF_bSS_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "wb") as tf:
            pickle.dump(dictionary_VSF_bSS,tf)
    else:
        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/VSF_bSS/{k}_{u}_VSF_bSS_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER,u=j), "rb") as tf:
            dictionary_VSF_bSS = pickle.load(tf)
            res_VSF_SS = dictionary_VSF_bSS['fit']
            VSF_bSS_DF_params = dictionary_VSF_bSS['fitting params']
    return VSF_bSS_DF_params

# %%
def test_multi(j):
    print(j)
    if len(dataframes[j].Time) <= 577:
        isExist = os.path.exists('/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/figures/SLSQP/{y}/{k}_{y}_event_plot_Multi_phase_SLSQP_shorter_90_15_MAY_23.pdf'.format(k=CREEPMETER[q],y=j))
        if not isExist:
            isExist2 = os.path.exists('/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{y}/{k}_{y}_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt'.format(k=CREEPMETER[q],y=j))
            if not isExist2:
                print('/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{y}/{k}_{y}_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt'.format(k=CREEPMETER[q],y=j))
                Creep_Phase_no = Creep_phases.iloc[j].dropna()
                number_of_phases = (len(Creep_Phase_no)/2)-1
                if 1<= number_of_phases <=2:
                    data_P0, data_P1, data_P2, data_P3, data_P4, creep_phase_new = rft.phase_splitter(Creep_Phase_no,dataframes[j])

                    LNV_DF_params = rft.initial_and_bounds(creep_phase_new,data_P0,data_P1,data_P2,data_P3,data_P4,'LNV')
                    PLV_DF_params = rft.initial_and_bounds(creep_phase_new,data_P0,data_P1,data_P2,data_P3,data_P4,'PLV')
                    VSF_SS_DF_params = rft.initial_and_bounds(creep_phase_new,data_P0,data_P1,data_P2,data_P3,data_P4,'VSF_SS')
                    VSF_bSS_DF_params = rft.initial_and_bounds(creep_phase_new,data_P0,data_P1,data_P2,data_P3,data_P4,'VSF_bSS')
                    VSF_aSS_DF_params = rft.initial_and_bounds(creep_phase_new,data_P0,data_P1,data_P2,data_P3,data_P4,'VSF_aSS')
                    RDF_DF_params = rft.initial_and_bounds(creep_phase_new,data_P0,data_P1,data_P2,data_P3,data_P4,'RDF')

                    if CREEPMETER[q] == 'XHR':
                        if j < 70:
                            C_matrix_inv = C_matrix_inv_2
                        else:
                            C_matrix_inv = C_matrix_inv_3
                    else:
                        C_matrix_inv = C_matrix_inv_CWN

                    rft.check_dir("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}".format(k=CREEPMETER[q]))
                    Rheologies_to_test = ['LNV','PLV','VSF_SS','VSF_bSS','VSF_aSS','RDF']#,'cb77']
                    if number_of_phases==1:
                        LNV_DF_params.drop(['Tau2','V02','T03','S3','Tau3','V03','T04','S4','Tau4','V04'], axis=1, inplace=True)
                        PLV_DF_params.drop(['Tau2','V02','n2','T03','S3','Tau3','V03','n3','T04','S4','Tau4','V04','n4'], axis=1, inplace=True)
                        VSF_SS_DF_params.drop(['Tau2','V02','T03','S3','Tau3','V03','T04','S4','Tau4','V04'], axis=1, inplace=True)
                        VSF_bSS_DF_params.drop(['Tau2','V02','A_B2','T03','S3','Tau3','V03','A_B3','T04','S4','Tau4','V04','A_B4'], axis=1, inplace=True)
                        VSF_aSS_DF_params.drop(['Ta2','V02','t2','T03','S3','Ta3','V03','t3','T04','S4','Ta4','V04','t4'], axis=1, inplace=True)
                        RDF_DF_params.drop(['Ta2','V02','V0/VL2','T03','S3','Ta3','V03','V0/VL3','T04','S4','Ta4','V04','V0/VL4'], axis=1, inplace=True)


                        for z in range(len(Rheologies_to_test)):
                            rft.check_dir("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/{x}".format(k=CREEPMETER[q],u=j,x=Rheologies_to_test[z]))

                        LNV_params_tried = np.zeros(len(LNV_DF_params.loc['initial'].index.tolist()))
                        PLV_params_tried = np.zeros(len(PLV_DF_params.loc['initial'].index.tolist()))
                        VSF_SS_params_tried = np.zeros(len(VSF_SS_DF_params.loc['initial'].index.tolist()))
                        VSF_bSS_params_tried = np.zeros(len(VSF_bSS_DF_params.loc['initial'].index.tolist()))
                        VSF_aSS_params_tried = np.zeros(len(VSF_aSS_DF_params.loc['initial'].index.tolist()))
                        RDF_params_tried = np.zeros(len(RDF_DF_params.loc['initial'].index.tolist()))

                        columns_LNV = LNV_DF_params.loc['initial'].index.tolist()
                        columns_PLV = PLV_DF_params.loc['initial'].index.tolist()
                        columns_VSF_SS = VSF_SS_DF_params.loc['initial'].index.tolist()
                        columns_VSF_bSS = VSF_bSS_DF_params.loc['initial'].index.tolist()
                        columns_VSF_aSS = VSF_aSS_DF_params.loc['initial'].index.tolist()
                        columns_RDF = RDF_DF_params.loc['initial'].index.tolist()

                        rft.check_dir("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}".format(k=CREEPMETER[q],u=j))

                        def atest(f_new, x_new, f_old, x_old):
                            if f_old < f_new:
                                return False
                            else:
                                return True

                        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/LNV/{k}_{u}_LNV_misfit_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER[q],u=j),'a') as file_LNV:
                            LNV_DF_params = LNV_fitter(np.array(dataframes[j].Time),np.array(dataframes[j].Slip), C_matrix_inv,number_of_phases,columns_LNV,j,CREEPMETER[q],LNV_DF_params,atest,file_LNV)

                        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/PLV/{k}_{u}_PLV_misfit_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER[q],u=j),'a') as file_PLV:
                            PLV_DF_params = PLV_fitter(np.array(dataframes[j].Time),np.array(dataframes[j].Slip), C_matrix_inv,number_of_phases,columns_PLV,j,CREEPMETER[q],PLV_DF_params,atest,file_PLV)

                        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/VSF_SS/{k}_{u}_VSF_SS_misfit_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER[q],u=j),'a') as file_VSF_SS:
                            VSF_SS_DF_params = VSF_SS_fitter(np.array(dataframes[j].Time),np.array(dataframes[j].Slip), C_matrix_inv,number_of_phases,columns_VSF_SS,j,CREEPMETER[q],\
                                                             VSF_SS_DF_params,atest,file_VSF_SS)

                        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/VSF_bSS/{k}_{u}_VSF_bSS_misfit_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER[q],u=j),'a') as file_VSF_bSS:
                            VSF_bSS_DF_params = VSF_bSS_fitter(np.array(dataframes[j].Time),np.array(dataframes[j].Slip), C_matrix_inv,number_of_phases,columns_VSF_bSS,j,CREEPMETER[q],\
                                                               VSF_bSS_DF_params,atest,file_VSF_bSS)

                        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/VSF_aSS/{k}_{u}_VSF_aSS_misfit_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER[q],u=j),'a') as file_VSF_aSS:
                            VSF_aSS_DF_params = VSF_aSS_fitter(np.array(dataframes[j].Time),np.array(dataframes[j].Slip), C_matrix_inv,number_of_phases,columns_VSF_aSS,j,CREEPMETER[q],\
                                                               VSF_aSS_DF_params,atest,file_VSF_aSS)

                        with open("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/fits/SLSQP/{u}/RDF/{k}_{u}_RDF_misfit_SLSQP_shorter_90_15_MAY_23.txt".format(k=CREEPMETER[q],u=j),'a') as file_RDF:
                            RDF_DF_params = RDF_fitter(np.array(dataframes[j].Time),np.array(dataframes[j].Slip), C_matrix_inv,number_of_phases,columns_RDF,j,CREEPMETER[q],RDF_DF_params,atest,file_RDF)
                        
                        test_t = np.arange(0,max(dataframes[j].Time.iloc[1:]),0.01)
                        rft.check_dir("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/figures/SLSQP".format(k=CREEPMETER[q]))
                        
                        slip_LNV = rft.LNV_dromedary_plot(LNV_DF_params.loc['fitted'],test_t,number_of_phases)
                        slip_PLV = rft.PLV_dromedary_plot(PLV_DF_params.loc['fitted'],test_t,number_of_phases)
                        slip_VSF = rft.VSF_dromedary_plot(VSF_SS_DF_params.loc['fitted'],test_t,number_of_phases)
                        slip_VSF_bSS = rft.VSF_bSS_dromedary_plot(VSF_bSS_DF_params.loc['fitted'],test_t,number_of_phases)
                        slip_VSF_aSS = rft.VSF_aSS_dromedary_plot(VSF_aSS_DF_params.loc['fitted'],test_t,number_of_phases)
                        slip_RDF = rft.RDF_dromedary_plot(RDF_DF_params.loc['fitted'],test_t,number_of_phases)
                        #slip_cb77 = rft.CB77_dromedary_plot(cb77_DF_params.loc['fitted'],test_t,number_of_phases)

                        colors = ['#74add1','#313695','#a50026','#d73027','#f46d43','#fdae61']

                        print('saving figure {k}'.format(k=j))        
                        plt.figure()
                        plt.scatter(dataframes[j].Time-2,dataframes[j].Slip, label='Observed Data',s=5,color='#000000', zorder=100)   
                        plt.plot(test_t-2,slip_LNV,label = 'Linear Viscous Flow', color = colors[0], linewidth=2, linestyle = '-')
                        plt.plot(test_t-2,slip_PLV,label='Power-law Viscous Flow', color = colors[1], linewidth=2, linestyle = '-')
                        plt.plot(test_t-2,slip_VSF,label = 'Velocity Strengthening Friction\n - steady state', color = colors[2], linewidth=2, linestyle = '-')
                        plt.plot(test_t-2,slip_VSF_aSS,label = 'R+S - Stress >> Steady State', color = colors[3], linewidth=2, linestyle = '-')
                        plt.plot(test_t-2,slip_VSF_bSS,label = 'R+S - Stress << Steady State', color = colors[4], linewidth=2, linestyle = '-')
                        plt.plot(test_t-2,slip_RDF,label = 'RDF', color = colors[5], linewidth=2, linestyle = '-')
                        plt.legend(fontsize=11)
                        plt.xlabel('Time since start of event, hrs', fontsize=14)
                        plt.ylabel('Slip, mm',fontsize=14)
                        plt.xticks(fontsize=14)
                        plt.yticks(fontsize=14)
                        plt.title('{K}_{P}'.format(K = CREEPMETER[q], P = j ),fontsize=18)
                        figure = plt.gcf()  # get current figure
                        figure.set_size_inches(6,6)
                        plt.tight_layout()
                        plt.savefig("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/figures/SLSQP/{k}_{u}_event_plot_Multi_phase_SLSQP_shorter_90_15_MAY_23.pdf".format(k=CREEPMETER[q],u=j),format='pdf')
                        plt.savefig("/home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/{k}/figures/SLSQP/{k}_{u}_event_plot_Multi_phase_SLSQP_shorter_90_15_MAY_23.png".format(k=CREEPMETER[q],u=j),format='pdf')
                        plt.close('all')
    return

# %%
dictionary_all_events = {}
if __name__ == '__main__':
    with Pool(1) as pool:                         # Create a multiprocessing Pool           
        pool.map(test_multi, dataframes)
# Out:
# 0
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/0/XHR_0_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 1
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/1/XHR_1_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 2
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/2/XHR_2_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 2
# Current date and time :
# 2023-05-15 16:32:01
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Linear_viscous'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 27:
# @jit(nopython=True,error_model = 'numpy')
# def Linear_viscous(optimized_par,OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Linear_viscous'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 27:
# @jit(nopython=True,error_model = 'numpy')
# def Linear_viscous(optimized_par,OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# Power-law Viscous: 2
# Current date and time :
# 2023-05-15 16:32:03
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Power_law_viscous'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 44:
# @jit(nopython=True,error_model = 'numpy')
# def Power_law_viscous(optimized_par,OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Power_law_viscous'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 44:
# @jit(nopython=True,error_model = 'numpy')
# def Power_law_viscous(optimized_par,OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# VSF-SS: 2
# Current date and time :
# 2023-05-15 16:32:04
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Velocity_strengthening_friction'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 54:
# @jit(nopython=True,error_model = 'numpy')
# def Velocity_strengthening_friction(optimized_par,OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Velocity_strengthening_friction'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 54:
# @jit(nopython=True,error_model = 'numpy')
# def Velocity_strengthening_friction(optimized_par,OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# VSF-bSS: 2
# Current date and time :
# 2023-05-15 16:32:05
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Velocity_strengthening_friction_2'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 64:
# @jit(nopython=True,error_model = 'numpy')
# def Velocity_strengthening_friction_2(optimized_par,OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Velocity_strengthening_friction_2'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 64:
# @jit(nopython=True,error_model = 'numpy')
# def Velocity_strengthening_friction_2(optimized_par,OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# VSF_aSS: 2
# Current date and time :
# 2023-05-15 16:32:06
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Velocity_strengthening_friction_3'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 75:
# @jit(nopython=True,error_model = 'numpy')
# def Velocity_strengthening_friction_3(optimized_par, OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Velocity_strengthening_friction_3'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 75:
# @jit(nopython=True,error_model = 'numpy')
# def Velocity_strengthening_friction_3(optimized_par, OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# RDF: 2
# Current date and time :
# 2023-05-15 16:32:07
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Rate_dependent_friction'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 86:
# @jit(nopython=True,error_model = 'numpy')
# def Rate_dependent_friction(optimized_par, OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/dan2/lib/python3.10/site-packages/numba/core/ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'optimized_par' of function 'Rate_dependent_friction'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "Rheology_fitting_toolkit.py", line 86:
# @jit(nopython=True,error_model = 'numpy')
# def Rate_dependent_friction(optimized_par, OBS_Time):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# saving figure 2
# 3
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/3/XHR_3_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 4
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/4/XHR_4_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 4
# Current date and time :
# 2023-05-15 16:32:09
# Power-law Viscous: 4
# Current date and time :
# 2023-05-15 16:32:11
# VSF-SS: 4
# Current date and time :
# 2023-05-15 16:32:13
# VSF-bSS: 4
# Current date and time :
# 2023-05-15 16:32:14
# VSF_aSS: 4
# Current date and time :
# 2023-05-15 16:32:16
# RDF: 4
# Current date and time :
# 2023-05-15 16:32:18
# saving figure 4
# 5
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/5/XHR_5_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 6
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/6/XHR_6_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 7
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/7/XHR_7_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 7
# Current date and time :
# 2023-05-15 16:32:21
# Power-law Viscous: 7
# Current date and time :
# 2023-05-15 16:32:24
# VSF-SS: 7
# Current date and time :
# 2023-05-15 16:32:28
# VSF-bSS: 7
# Current date and time :
# 2023-05-15 16:32:31
# VSF_aSS: 7
# Current date and time :
# 2023-05-15 16:32:36
# RDF: 7
# Current date and time :
# 2023-05-15 16:32:41
# saving figure 7
# 8
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/8/XHR_8_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 8
# Current date and time :
# 2023-05-15 16:32:48
# Power-law Viscous: 8
# Current date and time :
# 2023-05-15 16:32:49
# VSF-SS: 8
# Current date and time :
# 2023-05-15 16:32:50
# VSF-bSS: 8
# Current date and time :
# 2023-05-15 16:32:51
# VSF_aSS: 8
# Current date and time :
# 2023-05-15 16:32:52
# RDF: 8
# Current date and time :
# 2023-05-15 16:32:53
# saving figure 8
# 9
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/9/XHR_9_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 9
# Current date and time :
# 2023-05-15 16:32:56
# Power-law Viscous: 9
# Current date and time :
# 2023-05-15 16:32:57
# VSF-SS: 9
# Current date and time :
# 2023-05-15 16:32:58
# VSF-bSS: 9
# Current date and time :
# 2023-05-15 16:32:59
# VSF_aSS: 9
# Current date and time :
# 2023-05-15 16:33:00
# RDF: 9
# Current date and time :
# 2023-05-15 16:33:02
# saving figure 9
# 10
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/10/XHR_10_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 10
# Current date and time :
# 2023-05-15 16:33:05
# Power-law Viscous: 10
# Current date and time :
# 2023-05-15 16:33:06
# VSF-SS: 10
# Current date and time :
# 2023-05-15 16:33:07
# VSF-bSS: 10
# Current date and time :
# 2023-05-15 16:33:08
# VSF_aSS: 10
# Current date and time :
# 2023-05-15 16:33:09
# RDF: 10
# Current date and time :
# 2023-05-15 16:33:11
# saving figure 10
# 11
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/11/XHR_11_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 11
# Current date and time :
# 2023-05-15 16:33:13
# Power-law Viscous: 11
# Current date and time :
# 2023-05-15 16:33:13
# VSF-SS: 11
# Current date and time :
# 2023-05-15 16:33:14
# VSF-bSS: 11
# Current date and time :
# 2023-05-15 16:33:15
# VSF_aSS: 11
# Current date and time :
# 2023-05-15 16:33:16
# RDF: 11
# Current date and time :
# 2023-05-15 16:33:17
# saving figure 11
# 12
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/12/XHR_12_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 13
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/13/XHR_13_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 13
# Current date and time :
# 2023-05-15 16:33:21
# Power-law Viscous: 13
# Current date and time :
# 2023-05-15 16:33:22
# VSF-SS: 13
# Current date and time :
# 2023-05-15 16:33:23
# VSF-bSS: 13
# Current date and time :
# 2023-05-15 16:33:24
# VSF_aSS: 13
# Current date and time :
# 2023-05-15 16:33:26
# RDF: 13
# Current date and time :
# 2023-05-15 16:33:27
# saving figure 13
# 14
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/14/XHR_14_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 14
# Current date and time :
# 2023-05-15 16:33:29
# Power-law Viscous: 14
# Current date and time :
# 2023-05-15 16:33:30
# VSF-SS: 14
# Current date and time :
# 2023-05-15 16:33:31
# VSF-bSS: 14
# Current date and time :
# 2023-05-15 16:33:32
# VSF_aSS: 14
# Current date and time :
# 2023-05-15 16:33:33
# RDF: 14
# Current date and time :
# 2023-05-15 16:33:35
# saving figure 14
# 15
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/15/XHR_15_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 15
# Current date and time :
# 2023-05-15 16:33:38
# Power-law Viscous: 15
# Current date and time :
# 2023-05-15 16:33:39
# VSF-SS: 15
# Current date and time :
# 2023-05-15 16:33:39
# VSF-bSS: 15
# Current date and time :
# 2023-05-15 16:33:40
# VSF_aSS: 15
# Current date and time :
# 2023-05-15 16:33:41
# RDF: 15
# Current date and time :
# 2023-05-15 16:33:43
# saving figure 15
# 16
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/16/XHR_16_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 16
# Current date and time :
# 2023-05-15 16:33:45
# Power-law Viscous: 16
# Current date and time :
# 2023-05-15 16:33:46
# VSF-SS: 16
# Current date and time :
# 2023-05-15 16:33:47
# VSF-bSS: 16
# Current date and time :
# 2023-05-15 16:33:48
# VSF_aSS: 16
# Current date and time :
# 2023-05-15 16:33:49
# RDF: 16
# Current date and time :
# 2023-05-15 16:33:51
# saving figure 16
# 17
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/17/XHR_17_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 17
# Current date and time :
# 2023-05-15 16:33:53
# Power-law Viscous: 17
# Current date and time :
# 2023-05-15 16:33:55
# VSF-SS: 17
# Current date and time :
# 2023-05-15 16:33:56
# VSF-bSS: 17
# Current date and time :
# 2023-05-15 16:33:57
# VSF_aSS: 17
# Current date and time :
# 2023-05-15 16:33:59
# RDF: 17
# Current date and time :
# 2023-05-15 16:34:00
# saving figure 17
# 18
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/18/XHR_18_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 18
# Current date and time :
# 2023-05-15 16:34:02
# Power-law Viscous: 18
# Current date and time :
# 2023-05-15 16:34:03
# VSF-SS: 18
# Current date and time :
# 2023-05-15 16:34:04
# VSF-bSS: 18
# Current date and time :
# 2023-05-15 16:34:05
# VSF_aSS: 18
# Current date and time :
# 2023-05-15 16:34:06
# RDF: 18
# Current date and time :
# 2023-05-15 16:34:07
# saving figure 18
# 19
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/19/XHR_19_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 19
# Current date and time :
# 2023-05-15 16:34:09
# Power-law Viscous: 19
# Current date and time :
# 2023-05-15 16:34:11
# VSF-SS: 19
# Current date and time :
# 2023-05-15 16:34:12
# VSF-bSS: 19
# Current date and time :
# 2023-05-15 16:34:13
# VSF_aSS: 19
# Current date and time :
# 2023-05-15 16:34:15
# RDF: 19
# Current date and time :
# 2023-05-15 16:34:16
# saving figure 19
# 20
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/20/XHR_20_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 21
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/21/XHR_21_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 22
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/22/XHR_22_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 22
# Current date and time :
# 2023-05-15 16:34:19
# Power-law Viscous: 22
# Current date and time :
# 2023-05-15 16:34:20
# VSF-SS: 22
# Current date and time :
# 2023-05-15 16:34:20
# VSF-bSS: 22
# Current date and time :
# 2023-05-15 16:34:22
# VSF_aSS: 22
# Current date and time :
# 2023-05-15 16:34:23
# RDF: 22
# Current date and time :
# 2023-05-15 16:34:25
# saving figure 22
# 23
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/23/XHR_23_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 24
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/24/XHR_24_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 24
# Current date and time :
# 2023-05-15 16:34:27
# Power-law Viscous: 24
# Current date and time :
# 2023-05-15 16:34:28
# VSF-SS: 24
# Current date and time :
# 2023-05-15 16:34:29
# VSF-bSS: 24
# Current date and time :
# 2023-05-15 16:34:30
# VSF_aSS: 24
# Current date and time :
# 2023-05-15 16:34:31
# RDF: 24
# Current date and time :
# 2023-05-15 16:34:32
# saving figure 24
# 25
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/25/XHR_25_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 25
# Current date and time :
# 2023-05-15 16:34:35
# Power-law Viscous: 25
# Current date and time :
# 2023-05-15 16:34:35
# VSF-SS: 25
# Current date and time :
# 2023-05-15 16:34:36
# VSF-bSS: 25
# Current date and time :
# 2023-05-15 16:34:38
# VSF_aSS: 25
# Current date and time :
# 2023-05-15 16:34:39
# RDF: 25
# Current date and time :
# 2023-05-15 16:34:40
# saving figure 25
# 26
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/26/XHR_26_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 26
# Current date and time :
# 2023-05-15 16:34:43
# Power-law Viscous: 26
# Current date and time :
# 2023-05-15 16:34:44
# VSF-SS: 26
# Current date and time :
# 2023-05-15 16:34:45
# VSF-bSS: 26
# Current date and time :
# 2023-05-15 16:34:47
# VSF_aSS: 26
# Current date and time :
# 2023-05-15 16:34:49
# RDF: 26
# Current date and time :
# 2023-05-15 16:34:50
# saving figure 26
# 27
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/27/XHR_27_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 27
# Current date and time :
# 2023-05-15 16:34:52
# Power-law Viscous: 27
# Current date and time :
# 2023-05-15 16:34:54
# VSF-SS: 27
# Current date and time :
# 2023-05-15 16:34:54
# VSF-bSS: 27
# Current date and time :
# 2023-05-15 16:34:56
# VSF_aSS: 27
# Current date and time :
# 2023-05-15 16:34:57
# RDF: 27
# Current date and time :
# 2023-05-15 16:34:58
# saving figure 27
# 28
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/28/XHR_28_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 29
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/29/XHR_29_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 30
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/30/XHR_30_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 30
# Current date and time :
# 2023-05-15 16:35:01
# Power-law Viscous: 30
# Current date and time :
# 2023-05-15 16:35:03
# VSF-SS: 30
# Current date and time :
# 2023-05-15 16:35:03
# VSF-bSS: 30
# Current date and time :
# 2023-05-15 16:35:04
# VSF_aSS: 30
# Current date and time :
# 2023-05-15 16:35:06
# RDF: 30
# Current date and time :
# 2023-05-15 16:35:08
# saving figure 30
# 31
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/31/XHR_31_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 32
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/32/XHR_32_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 33
# 34
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/34/XHR_34_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 35
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/35/XHR_35_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 36
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/36/XHR_36_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 37
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/37/XHR_37_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 37
# Current date and time :
# 2023-05-15 16:35:10
# Power-law Viscous: 37
# Current date and time :
# 2023-05-15 16:35:11
# VSF-SS: 37
# Current date and time :
# 2023-05-15 16:35:12
# VSF-bSS: 37
# Current date and time :
# 2023-05-15 16:35:13
# VSF_aSS: 37
# Current date and time :
# 2023-05-15 16:35:14
# RDF: 37
# Current date and time :
# 2023-05-15 16:35:16
# saving figure 37
# 38
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/38/XHR_38_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 39
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/39/XHR_39_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 39
# Current date and time :
# 2023-05-15 16:35:17
# Power-law Viscous: 39
# Current date and time :
# 2023-05-15 16:35:19
# VSF-SS: 39
# Current date and time :
# 2023-05-15 16:35:19
# VSF-bSS: 39
# Current date and time :
# 2023-05-15 16:35:21
# VSF_aSS: 39
# Current date and time :
# 2023-05-15 16:35:23
# RDF: 39
# Current date and time :
# 2023-05-15 16:35:24
# saving figure 39
# 40
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/40/XHR_40_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 41
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/41/XHR_41_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 41
# Current date and time :
# 2023-05-15 16:35:27
# Power-law Viscous: 41
# Current date and time :
# 2023-05-15 16:35:29
# VSF-SS: 41
# Current date and time :
# 2023-05-15 16:35:30
# VSF-bSS: 41
# Current date and time :
# 2023-05-15 16:35:31
# VSF_aSS: 41
# Current date and time :
# 2023-05-15 16:35:32
# RDF: 41
# Current date and time :
# 2023-05-15 16:35:34
# saving figure 41
# 42
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/42/XHR_42_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 43
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/43/XHR_43_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 44
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/44/XHR_44_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 44
# Current date and time :
# 2023-05-15 16:35:38
# Power-law Viscous: 44
# Current date and time :
# 2023-05-15 16:35:39
# VSF-SS: 44
# Current date and time :
# 2023-05-15 16:35:40
# VSF-bSS: 44
# Current date and time :
# 2023-05-15 16:35:41
# VSF_aSS: 44
# Current date and time :
# 2023-05-15 16:35:43
# RDF: 44
# Current date and time :
# 2023-05-15 16:35:44
# saving figure 44
# 45
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/45/XHR_45_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 45
# Current date and time :
# 2023-05-15 16:35:47
# Power-law Viscous: 45
# Current date and time :
# 2023-05-15 16:35:48
# VSF-SS: 45
# Current date and time :
# 2023-05-15 16:35:49
# VSF-bSS: 45
# Current date and time :
# 2023-05-15 16:35:50
# VSF_aSS: 45
# Current date and time :
# 2023-05-15 16:35:52
# RDF: 45
# Current date and time :
# 2023-05-15 16:35:53
# saving figure 45
# 46
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/46/XHR_46_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 46
# Current date and time :
# 2023-05-15 16:35:55
# Power-law Viscous: 46
# Current date and time :
# 2023-05-15 16:35:56
# VSF-SS: 46
# Current date and time :
# 2023-05-15 16:35:57
# VSF-bSS: 46
# Current date and time :
# 2023-05-15 16:35:58
# VSF_aSS: 46
# Current date and time :
# 2023-05-15 16:35:59
# RDF: 46
# Current date and time :
# 2023-05-15 16:36:01
# saving figure 46
# 47
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/47/XHR_47_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 47
# Current date and time :
# 2023-05-15 16:36:03
# Power-law Viscous: 47
# Current date and time :
# 2023-05-15 16:36:04
# VSF-SS: 47
# Current date and time :
# 2023-05-15 16:36:05
# VSF-bSS: 47
# Current date and time :
# 2023-05-15 16:36:06
# VSF_aSS: 47
# Current date and time :
# 2023-05-15 16:36:07
# RDF: 47
# Current date and time :
# 2023-05-15 16:36:09
# saving figure 47
# 48
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/48/XHR_48_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 48
# Current date and time :
# 2023-05-15 16:36:11
# Power-law Viscous: 48
# Current date and time :
# 2023-05-15 16:36:14
# VSF-SS: 48
# Current date and time :
# 2023-05-15 16:36:15
# VSF-bSS: 48
# Current date and time :
# 2023-05-15 16:36:18
# VSF_aSS: 48
# Current date and time :
# 2023-05-15 16:36:22
# RDF: 48
# Current date and time :
# 2023-05-15 16:36:27
# saving figure 48
# 49
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/49/XHR_49_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 49
# Current date and time :
# 2023-05-15 16:36:34
# Power-law Viscous: 49
# Current date and time :
# 2023-05-15 16:36:35
# VSF-SS: 49
# Current date and time :
# 2023-05-15 16:36:35
# VSF-bSS: 49
# Current date and time :
# 2023-05-15 16:36:37
# VSF_aSS: 49
# Current date and time :
# 2023-05-15 16:36:38
# RDF: 49
# Current date and time :
# 2023-05-15 16:36:40
# saving figure 49
# 50
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/50/XHR_50_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 51
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/51/XHR_51_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 52
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/52/XHR_52_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 52
# Current date and time :
# 2023-05-15 16:36:42
# Power-law Viscous: 52
# Current date and time :
# 2023-05-15 16:36:44
# VSF-SS: 52
# Current date and time :
# 2023-05-15 16:36:44
# VSF-bSS: 52
# Current date and time :
# 2023-05-15 16:36:45
# VSF_aSS: 52
# Current date and time :
# 2023-05-15 16:36:47
# RDF: 52
# Current date and time :
# 2023-05-15 16:36:49
# saving figure 52
# 53
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/53/XHR_53_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 53
# Current date and time :
# 2023-05-15 16:36:51
# Power-law Viscous: 53
# Current date and time :
# 2023-05-15 16:36:52
# VSF-SS: 53
# Current date and time :
# 2023-05-15 16:36:53
# VSF-bSS: 53
# Current date and time :
# 2023-05-15 16:36:54
# VSF_aSS: 53
# Current date and time :
# 2023-05-15 16:36:55
# RDF: 53
# Current date and time :
# 2023-05-15 16:36:56
# saving figure 53
# 54
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/54/XHR_54_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 55
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/55/XHR_55_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 56
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/56/XHR_56_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 56
# Current date and time :
# 2023-05-15 16:37:00
# Power-law Viscous: 56
# Current date and time :
# 2023-05-15 16:37:01
# VSF-SS: 56
# Current date and time :
# 2023-05-15 16:37:02
# VSF-bSS: 56
# Current date and time :
# 2023-05-15 16:37:03
# VSF_aSS: 56
# Current date and time :
# 2023-05-15 16:37:05
# RDF: 56
# Current date and time :
# 2023-05-15 16:37:07
# saving figure 56
# 57
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/57/XHR_57_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 58
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/58/XHR_58_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 59
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/59/XHR_59_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 60
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/60/XHR_60_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 61
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/61/XHR_61_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 62
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/62/XHR_62_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 63
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/63/XHR_63_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 64
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/64/XHR_64_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 64
# Current date and time :
# 2023-05-15 16:37:10
# Power-law Viscous: 64
# Current date and time :
# 2023-05-15 16:37:13
# VSF-SS: 64
# Current date and time :
# 2023-05-15 16:37:15
# VSF-bSS: 64
# Current date and time :
# 2023-05-15 16:37:18
# VSF_aSS: 64
# Current date and time :
# 2023-05-15 16:37:22
# RDF: 64
# Current date and time :
# 2023-05-15 16:37:26
# saving figure 64
# 65
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/65/XHR_65_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 66
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/66/XHR_66_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 67
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/67/XHR_67_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 67
# Current date and time :
# 2023-05-15 16:37:32
# Power-law Viscous: 67
# Current date and time :
# 2023-05-15 16:37:33
# VSF-SS: 67
# Current date and time :
# 2023-05-15 16:37:33
# VSF-bSS: 67
# Current date and time :
# 2023-05-15 16:37:34
# VSF_aSS: 67
# Current date and time :
# 2023-05-15 16:37:35
# RDF: 67
# Current date and time :
# 2023-05-15 16:37:36
# saving figure 67
# 68
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/68/XHR_68_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 68
# Current date and time :
# 2023-05-15 16:37:39
# Power-law Viscous: 68
# Current date and time :
# 2023-05-15 16:37:40
# VSF-SS: 68
# Current date and time :
# 2023-05-15 16:37:42
# VSF-bSS: 68
# Current date and time :
# 2023-05-15 16:37:43
# VSF_aSS: 68
# Current date and time :
# 2023-05-15 16:37:45
# RDF: 68
# Current date and time :
# 2023-05-15 16:37:47
# saving figure 68
# 69
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/69/XHR_69_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 70
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/70/XHR_70_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 71
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/71/XHR_71_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 72
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/72/XHR_72_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 72
# Current date and time :
# 2023-05-15 16:37:50
# Power-law Viscous: 72
# Current date and time :
# 2023-05-15 16:37:52
# VSF-SS: 72
# Current date and time :
# 2023-05-15 16:37:53
# VSF-bSS: 72
# Current date and time :
# 2023-05-15 16:37:55
# VSF_aSS: 72
# Current date and time :
# 2023-05-15 16:37:56
# RDF: 72
# Current date and time :
# 2023-05-15 16:37:58
# saving figure 72
# 73
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/73/XHR_73_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 74
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/74/XHR_74_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 75
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/75/XHR_75_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 76
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/76/XHR_76_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 77
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/77/XHR_77_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 77
# Current date and time :
# 2023-05-15 16:38:01
# Power-law Viscous: 77
# Current date and time :
# 2023-05-15 16:38:02
# VSF-SS: 77
# Current date and time :
# 2023-05-15 16:38:04
# VSF-bSS: 77
# Current date and time :
# 2023-05-15 16:38:06
# VSF_aSS: 77
# Current date and time :
# 2023-05-15 16:38:08
# RDF: 77
# Current date and time :
# 2023-05-15 16:38:10
# saving figure 77
# 78
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/78/XHR_78_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 79
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/79/XHR_79_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 79
# Current date and time :
# 2023-05-15 16:38:13
# Power-law Viscous: 79
# Current date and time :
# 2023-05-15 16:38:14
# VSF-SS: 79
# Current date and time :
# 2023-05-15 16:38:15
# VSF-bSS: 79
# Current date and time :
# 2023-05-15 16:38:17
# VSF_aSS: 79
# Current date and time :
# 2023-05-15 16:38:19
# RDF: 79
# Current date and time :
# 2023-05-15 16:38:20
# saving figure 79
# 80
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/80/XHR_80_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 81
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/81/XHR_81_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 81
# Current date and time :
# 2023-05-15 16:38:22
# Power-law Viscous: 81
# Current date and time :
# 2023-05-15 16:38:24
# VSF-SS: 81
# Current date and time :
# 2023-05-15 16:38:25
# VSF-bSS: 81
# Current date and time :
# 2023-05-15 16:38:26
# VSF_aSS: 81
# Current date and time :
# 2023-05-15 16:38:28
# RDF: 81
# Current date and time :
# 2023-05-15 16:38:29
# saving figure 81
# 82
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/82/XHR_82_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 83
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/83/XHR_83_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 84
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/84/XHR_84_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 85
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/85/XHR_85_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 86
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/86/XHR_86_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 87
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/87/XHR_87_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 88
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/88/XHR_88_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 88
# Current date and time :
# 2023-05-15 16:38:32
# Power-law Viscous: 88
# Current date and time :
# 2023-05-15 16:38:32
# VSF-SS: 88
# Current date and time :
# 2023-05-15 16:38:33
# VSF-bSS: 88
# Current date and time :
# 2023-05-15 16:38:34
# VSF_aSS: 88
# Current date and time :
# 2023-05-15 16:38:36
# RDF: 88
# Current date and time :
# 2023-05-15 16:38:37
# saving figure 88
# 89
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/89/XHR_89_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 90
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/90/XHR_90_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 90
# Current date and time :
# 2023-05-15 16:38:39
# Power-law Viscous: 90
# Current date and time :
# 2023-05-15 16:38:41
# VSF-SS: 90
# Current date and time :
# 2023-05-15 16:38:42
# VSF-bSS: 90
# Current date and time :
# 2023-05-15 16:38:44
# VSF_aSS: 90
# Current date and time :
# 2023-05-15 16:38:46
# RDF: 90
# Current date and time :
# 2023-05-15 16:38:48
# saving figure 90
# 91
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/91/XHR_91_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 91
# Current date and time :
# 2023-05-15 16:38:50
# Power-law Viscous: 91
# Current date and time :
# 2023-05-15 16:38:52
# VSF-SS: 91
# Current date and time :
# 2023-05-15 16:38:52
# VSF-bSS: 91
# Current date and time :
# 2023-05-15 16:38:54
# VSF_aSS: 91
# Current date and time :
# 2023-05-15 16:38:56
# RDF: 91
# Current date and time :
# 2023-05-15 16:38:58
# saving figure 91
# 92
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/92/XHR_92_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 93
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/93/XHR_93_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 93
# Current date and time :
# 2023-05-15 16:39:00
# Power-law Viscous: 93
# Current date and time :
# 2023-05-15 16:39:02
# VSF-SS: 93
# Current date and time :
# 2023-05-15 16:39:04
# VSF-bSS: 93
# Current date and time :
# 2023-05-15 16:39:06
# VSF_aSS: 93
# Current date and time :
# 2023-05-15 16:39:08
# RDF: 93
# Current date and time :
# 2023-05-15 16:39:10
# saving figure 93
# 94
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/94/XHR_94_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 94
# Current date and time :
# 2023-05-15 16:39:13
# Power-law Viscous: 94
# Current date and time :
# 2023-05-15 16:39:15
# VSF-SS: 94
# Current date and time :
# 2023-05-15 16:39:15
# VSF-bSS: 94
# Current date and time :
# 2023-05-15 16:39:17
# VSF_aSS: 94
# Current date and time :
# 2023-05-15 16:39:19
# RDF: 94
# Current date and time :
# 2023-05-15 16:39:21
# saving figure 94
# 95
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/95/XHR_95_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 95
# Current date and time :
# 2023-05-15 16:39:23
# Power-law Viscous: 95
# Current date and time :
# 2023-05-15 16:39:25
# VSF-SS: 95
# Current date and time :
# 2023-05-15 16:39:25
# VSF-bSS: 95
# Current date and time :
# 2023-05-15 16:39:27
# VSF_aSS: 95
# Current date and time :
# 2023-05-15 16:39:28
# RDF: 95
# Current date and time :
# 2023-05-15 16:39:30
# saving figure 95
# 96
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/96/XHR_96_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 96
# Current date and time :
# 2023-05-15 16:39:32
# Power-law Viscous: 96
# Current date and time :
# 2023-05-15 16:39:34
# VSF-SS: 96
# Current date and time :
# 2023-05-15 16:39:35
# VSF-bSS: 96
# Current date and time :
# 2023-05-15 16:39:37
# VSF_aSS: 96
# Current date and time :
# 2023-05-15 16:39:39
# RDF: 96
# Current date and time :
# 2023-05-15 16:39:41
# saving figure 96
# 97
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/97/XHR_97_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 97
# Current date and time :
# 2023-05-15 16:39:44
# Power-law Viscous: 97
# Current date and time :
# 2023-05-15 16:39:46
# VSF-SS: 97
# Current date and time :
# 2023-05-15 16:39:46
# VSF-bSS: 97
# Current date and time :
# 2023-05-15 16:39:48
# VSF_aSS: 97
# Current date and time :
# 2023-05-15 16:39:50
# RDF: 97
# Current date and time :
# 2023-05-15 16:39:52
# saving figure 97
# 98
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/98/XHR_98_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 98
# Current date and time :
# 2023-05-15 16:39:54
# Power-law Viscous: 98
# Current date and time :
# 2023-05-15 16:39:56
# VSF-SS: 98
# Current date and time :
# 2023-05-15 16:39:57
# VSF-bSS: 98
# Current date and time :
# 2023-05-15 16:39:59
# VSF_aSS: 98
# Current date and time :
# 2023-05-15 16:40:01
# RDF: 98
# Current date and time :
# 2023-05-15 16:40:03
# saving figure 98
# 99
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/99/XHR_99_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 100
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/100/XHR_100_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 101
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/101/XHR_101_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 101
# Current date and time :
# 2023-05-15 16:40:05
# Power-law Viscous: 101
# Current date and time :
# 2023-05-15 16:40:06
# VSF-SS: 101
# Current date and time :
# 2023-05-15 16:40:06
# VSF-bSS: 101
# Current date and time :
# 2023-05-15 16:40:07
# VSF_aSS: 101
# Current date and time :
# 2023-05-15 16:40:08
# RDF: 101
# Current date and time :
# 2023-05-15 16:40:09
# saving figure 101
# 102
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/102/XHR_102_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 102
# Current date and time :
# 2023-05-15 16:40:12
# Power-law Viscous: 102
# Current date and time :
# 2023-05-15 16:40:13
# VSF-SS: 102
# Current date and time :
# 2023-05-15 16:40:14
# VSF-bSS: 102
# Current date and time :
# 2023-05-15 16:40:16
# VSF_aSS: 102
# Current date and time :
# 2023-05-15 16:40:17
# RDF: 102
# Current date and time :
# 2023-05-15 16:40:19
# saving figure 102
# 103
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/103/XHR_103_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 104
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/104/XHR_104_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 105
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/105/XHR_105_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# Linear Viscous: 105
# Current date and time :
# 2023-05-15 16:40:22
# Power-law Viscous: 105
# Current date and time :
# 2023-05-15 16:40:24
# VSF-SS: 105
# Current date and time :
# 2023-05-15 16:40:25
# VSF-bSS: 105
# Current date and time :
# 2023-05-15 16:40:26
# VSF_aSS: 105
# Current date and time :
# 2023-05-15 16:40:28
# RDF: 105
# Current date and time :
# 2023-05-15 16:40:30
# saving figure 105
# 106
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/106/XHR_106_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 107
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/107/XHR_107_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 108
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/108/XHR_108_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 109
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/109/XHR_109_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 110
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/110/XHR_110_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 111
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/111/XHR_111_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 112
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/112/XHR_112_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
# 113
# /home/earthquakes2/homes/Dan/Rheology/Single_rheology_28_APR_23/XHR/fits/SLSQP/113/XHR_113_fit_dictionary_multi_phase_SLSQP_shorter_90_15_MAY_23.txt
